# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
import os
import cv2
import struct
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
dataset_dir = 'dataset/'

img_size = (224, 224)

# %%
def load_pose_txt(file_path):
    """Load pose from text file."""
    with open(file_path, 'r') as f:
        pose = [float(x) for x in f.readline().split()]
    return np.array(pose)

def load_depth_bin(file_path):
    """Load depth data from binary file, attempt to reshape, and resize to (224, 224)."""
    try:
        with open(file_path, 'rb') as f:
            buffer = f.read()
            print(f"File: {file_path}, Buffer size: {len(buffer)} bytes")

            # Try interpreting the buffer as float32 data
            try:
                depth_data = np.frombuffer(buffer, dtype=np.float32)
                print(f"Loaded data as float32 with length: {len(depth_data)}")
            except ValueError:
                print(f"Could not interpret {file_path} as float32.")
                return None

            # Attempt to reshape the data to its likely original dimensions
            possible_shapes = [(224, 224), (640, 480)]  # Add possible dimensions here
            for shape in possible_shapes:
                if depth_data.size == np.prod(shape):
                    depth_img = depth_data.reshape(shape)
                    print(f"Successfully reshaped to {shape}")
                    # Resize the depth image to the target shape (224, 224)
                    depth_img_resized = cv2.resize(depth_img, (224, 224))
                    return depth_img_resized

            print(f"Could not reshape depth data: Could not reshape array of size {depth_data.size} into known shapes")
            return None  # Skip this file

    except Exception as e:
        print(f"Error loading depth data from {file_path}: {e}")
        return None

def preprocess_biwi_dataset(dataset_dir):
    """Traverse the BIWI dataset directory and preprocess the images and depth maps."""
    rgb_images = []
    depth_images = []
    poses = []
    masks = []
    
    sub_dirs = ['faces_0', 'db_annotations', 'head_pose_marks']

    for sub_dir in sub_dirs:
        sub_dir_path = os.path.join(dataset_dir, sub_dir)

        if not os.path.isdir(sub_dir_path):
            print(f"Skipping non-directory {sub_dir_path}")
            continue

        for folder in os.listdir(sub_dir_path):
            folder_path = os.path.join(sub_dir_path, folder)
            
            if not os.path.isdir(folder_path):
                print(f"Skipping non-directory {folder_path}")
                continue

            for file_name in os.listdir(folder_path):
                if sub_dir == 'faces_0' and file_name.endswith('_rgb.png'):
                    rgb_img_path = os.path.join(folder_path, file_name)
                    rgb_img = cv2.imread(rgb_img_path)
                    rgb_img = cv2.resize(rgb_img, (224, 224))
                    rgb_images.append(rgb_img)

                    # Load corresponding Depth data
                    depth_bin_path = rgb_img_path.replace('_rgb.png', '_depth.bin')
                    depth_img = load_depth_bin(depth_bin_path)
                    if depth_img is not None:
                        depth_images.append(depth_img)

                elif sub_dir == 'db_annotations' and file_name.endswith('_pose.bin'):
                    pose_bin_path = os.path.join(folder_path, file_name)
                    pose_data = np.fromfile(pose_bin_path, dtype=np.float32)
                    poses.append(pose_data)

                elif sub_dir == 'head_pose_marks' and file_name.endswith('.png'):
                    mask_img_path = os.path.join(folder_path, file_name)
                    mask_img = cv2.imread(mask_img_path, cv2.IMREAD_GRAYSCALE)
                    mask_img = cv2.resize(mask_img, (224, 224))
                    masks.append(mask_img)
                    
    return rgb_images, depth_images, poses, masks

# %%
# Use the function to preprocess the dataset
dataset_dir = 'dataset/'
rgb_images, depth_images, poses, masks = preprocess_biwi_dataset(dataset_dir)

# Normalize images and masks
rgb_images = rgb_images / 255.0
depth_images = depth_images / np.max(depth_images)
masks = masks / 255.0

# Prepare TensorFlow dataset
train_dataset = tf.data.Dataset.from_tensor_slices((rgb_images, depth_images, masks))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# File: dataset/faces_0\01\frame_00003_depth.bin, Buffer size: 116280 bytes
# Loaded data as float32 with length: 29070
# Could not reshape depth data: Could not reshape array of size 29070 into known shapes
# File: dataset/faces_0\01\frame_00004_depth.bin, Buffer size: 115952 bytes
# Loaded data as float32 with length: 28988
# Could not reshape depth data: Could not reshape array of size 28988 into known shapes
# File: dataset/faces_0\01\frame_00005_depth.bin, Buffer size: 115992 bytes
# Loaded data as float32 with length: 28998
# Could not reshape depth data: Could not reshape array of size 28998 into known shapes
# File: dataset/faces_0\01\frame_00006_depth.bin, Buffer size: 116056 bytes
# Loaded data as float32 with length: 29014
# Could not reshape depth data: Could not reshape array of size 29014 into known shapes
# File: dataset/faces_0\01\frame_00007_depth.bin, Buffer size: 115896 bytes
# Loaded data as float32 with length: 28974
# Could not reshape depth data: Could not reshape array of size 28974 into known shapes
# File: dataset/faces_0\01\frame_00008_depth.bin, Buffer size: 115770 bytes
# Could not interpret dataset/faces_0\01\frame_00008_depth.bin as float32.
# File: dataset/faces_0\01\frame_00009_depth.bin, Buffer size: 115984 bytes
# Loaded data as float32 with length: 28996
# Could not reshape depth data: Could not reshape array of size 28996 into known shapes
# File: dataset/faces_0\01\frame_00010_depth.bin, Buffer size: 115944 bytes
# Loaded data as float32 with length: 28986
# Could not reshape depth data: Could not reshape array of size 28986 into known shapes
# File: dataset/faces_0\01\frame_00011_depth.bin, Buffer size: 115902 bytes
# Could not interpret dataset/faces_0\01\frame_00011_depth.bin as float32.
# File: dataset/faces_0\01\frame_00012_depth.bin, Buffer size: 115878 bytes
# Could not interpret dataset/faces_0\01\frame_00012_depth.bin as float32.
# File: dataset/faces_0\01\frame_00013_depth.bin, Buffer size: 116380 bytes
# Loaded data as float32 with length: 29095
# Could not reshape depth data: Could not reshape array of size 29095 into known shapes
# File: dataset/faces_0\01\frame_00014_depth.bin, Buffer size: 116286 bytes
# Could not interpret dataset/faces_0\01\frame_00014_depth.bin as float32.
# File: dataset/faces_0\01\frame_00015_depth.bin, Buffer size: 116278 bytes
# Could not interpret dataset/faces_0\01\frame_00015_depth.bin as float32.
# File: dataset/faces_0\01\frame_00016_depth.bin, Buffer size: 116486 bytes
# Could not interpret dataset/faces_0\01\frame_00016_depth.bin as float32.
# File: dataset/faces_0\01\frame_00017_depth.bin, Buffer size: 116362 bytes
# Could not interpret dataset/faces_0\01\frame_00017_depth.bin as float32.
# File: dataset/faces_0\01\frame_00018_depth.bin, Buffer size: 116030 bytes
# Could not interpret dataset/faces_0\01\frame_00018_depth.bin as float32.
# File: dataset/faces_0\01\frame_00019_depth.bin, Buffer size: 116276 bytes
# Loaded data as float32 with length: 29069
# Could not reshape depth data: Could not reshape array of size 29069 into known shapes
# File: dataset/faces_0\01\frame_00020_depth.bin, Buffer size: 116530 bytes
# Could not interpret dataset/faces_0\01\frame_00020_depth.bin as float32.
# File: dataset/faces_0\01\frame_00021_depth.bin, Buffer size: 117206 bytes
# Could not interpret dataset/faces_0\01\frame_00021_depth.bin as float32.
# File: dataset/faces_0\01\frame_00022_depth.bin, Buffer size: 116604 bytes
# Loaded data as float32 with length: 29151
# Could not reshape depth data: Could not reshape array of size 29151 into known shapes
# File: dataset/faces_0\01\frame_00023_depth.bin, Buffer size: 117194 bytes
# Could not interpret dataset/faces_0\01\frame_00023_depth.bin as float32.
# File: dataset/faces_0\01\frame_00024_depth.bin, Buffer size: 117922 bytes
# Could not interpret dataset/faces_0\01\frame_00024_depth.bin as float32.
# File: dataset/faces_0\01\frame_00025_depth.bin, Buffer size: 118568 bytes
# Loaded data as float32 with length: 29642
# Could not reshape depth data: Could not reshape array of size 29642 into known shapes
# File: dataset/faces_0\01\frame_00026_depth.bin, Buffer size: 119060 bytes
# Loaded data as float32 with length: 29765
# Could not reshape depth data: Could not reshape array of size 29765 into known shapes
# File: dataset/faces_0\01\frame_00027_depth.bin, Buffer size: 120208 bytes
# Loaded data as float32 with length: 30052
# Could not reshape depth data: Could not reshape array of size 30052 into known shapes
# File: dataset/faces_0\01\frame_00028_depth.bin, Buffer size: 119536 bytes
# Loaded data as float32 with length: 29884
# Could not reshape depth data: Could not reshape array of size 29884 into known shapes
# File: dataset/faces_0\01\frame_00029_depth.bin, Buffer size: 119378 bytes
# Could not interpret dataset/faces_0\01\frame_00029_depth.bin as float32.
# File: dataset/faces_0\01\frame_00030_depth.bin, Buffer size: 119926 bytes
# Could not interpret dataset/faces_0\01\frame_00030_depth.bin as float32.
# File: dataset/faces_0\01\frame_00031_depth.bin, Buffer size: 119850 bytes
# Could not interpret dataset/faces_0\01\frame_00031_depth.bin as float32.
# File: dataset/faces_0\01\frame_00032_depth.bin, Buffer size: 119326 bytes
# Could not interpret dataset/faces_0\01\frame_00032_depth.bin as float32.
# File: dataset/faces_0\01\frame_00033_depth.bin, Buffer size: 119874 bytes
# Could not interpret dataset/faces_0\01\frame_00033_depth.bin as float32.
# File: dataset/faces_0\01\frame_00034_depth.bin, Buffer size: 119000 bytes
# Loaded data as float32 with length: 29750
# Could not reshape depth data: Could not reshape array of size 29750 into known shapes
# File: dataset/faces_0\01\frame_00035_depth.bin, Buffer size: 119918 bytes
# Could not interpret dataset/faces_0\01\frame_00035_depth.bin as float32.
# File: dataset/faces_0\01\frame_00036_depth.bin, Buffer size: 119958 bytes
# Could not interpret dataset/faces_0\01\frame_00036_depth.bin as float32.
# File: dataset/faces_0\01\frame_00037_depth.bin, Buffer size: 119162 bytes
# Could not interpret dataset/faces_0\01\frame_00037_depth.bin as float32.
# File: dataset/faces_0\01\frame_00038_depth.bin, Buffer size: 118956 bytes
# Loaded data as float32 with length: 29739
# Could not reshape depth data: Could not reshape array of size 29739 into known shapes
# File: dataset/faces_0\01\frame_00039_depth.bin, Buffer size: 118872 bytes
# Loaded data as float32 with length: 29718
# Could not reshape depth data: Could not reshape array of size 29718 into known shapes
# File: dataset/faces_0\01\frame_00040_depth.bin, Buffer size: 118816 bytes
# Loaded data as float32 with length: 29704
# Could not reshape depth data: Could not reshape array of size 29704 into known shapes
# File: dataset/faces_0\01\frame_00041_depth.bin, Buffer size: 118398 bytes
# Could not interpret dataset/faces_0\01\frame_00041_depth.bin as float32.
# File: dataset/faces_0\01\frame_00042_depth.bin, Buffer size: 118808 bytes
# Loaded data as float32 with length: 29702
# Could not reshape depth data: Could not reshape array of size 29702 into known shapes
# File: dataset/faces_0\01\frame_00043_depth.bin, Buffer size: 118650 bytes
# Could not interpret dataset/faces_0\01\frame_00043_depth.bin as float32.
# File: dataset/faces_0\01\frame_00044_depth.bin, Buffer size: 117764 bytes
# Loaded data as float32 with length: 29441
# Could not reshape depth data: Could not reshape array of size 29441 into known shapes
# File: dataset/faces_0\01\frame_00045_depth.bin, Buffer size: 118208 bytes
# Loaded data as float32 with length: 29552
# Could not reshape depth data: Could not reshape array of size 29552 into known shapes
# File: dataset/faces_0\01\frame_00046_depth.bin, Buffer size: 117860 bytes
# Loaded data as float32 with length: 29465
# Could not reshape depth data: Could not reshape array of size 29465 into known shapes
# File: dataset/faces_0\01\frame_00047_depth.bin, Buffer size: 117746 bytes
# Could not interpret dataset/faces_0\01\frame_00047_depth.bin as float32.
# File: dataset/faces_0\01\frame_00048_depth.bin, Buffer size: 117924 bytes
# Loaded data as float32 with length: 29481
# Could not reshape depth data: Could not reshape array of size 29481 into known shapes
# File: dataset/faces_0\01\frame_00049_depth.bin, Buffer size: 117662 bytes
# Could not interpret dataset/faces_0\01\frame_00049_depth.bin as float32.
# File: dataset/faces_0\01\frame_00050_depth.bin, Buffer size: 117244 bytes
# Loaded data as float32 with length: 29311
# Could not reshape depth data: Could not reshape array of size 29311 into known shapes
# File: dataset/faces_0\01\frame_00051_depth.bin, Buffer size: 117480 bytes
# Loaded data as float32 with length: 29370
# Could not reshape depth data: Could not reshape array of size 29370 into known shapes
# File: dataset/faces_0\01\frame_00052_depth.bin, Buffer size: 117478 bytes
# Could not interpret dataset/faces_0\01\frame_00052_depth.bin as float32.
# File: dataset/faces_0\01\frame_00053_depth.bin, Buffer size: 117520 bytes
# Loaded data as float32 with length: 29380
# Could not reshape depth data: Could not reshape array of size 29380 into known shapes
# File: dataset/faces_0\01\frame_00054_depth.bin, Buffer size: 117796 bytes
# Loaded data as float32 with length: 29449
# Could not reshape depth data: Could not reshape array of size 29449 into known shapes
# File: dataset/faces_0\01\frame_00055_depth.bin, Buffer size: 117530 bytes
# Could not interpret dataset/faces_0\01\frame_00055_depth.bin as float32.
# File: dataset/faces_0\01\frame_00056_depth.bin, Buffer size: 117652 bytes
# Loaded data as float32 with length: 29413
# Could not reshape depth data: Could not reshape array of size 29413 into known shapes
# File: dataset/faces_0\01\frame_00057_depth.bin, Buffer size: 117412 bytes
# Loaded data as float32 with length: 29353
# Could not reshape depth data: Could not reshape array of size 29353 into known shapes
# File: dataset/faces_0\01\frame_00058_depth.bin, Buffer size: 117268 bytes
# Loaded data as float32 with length: 29317
# Could not reshape depth data: Could not reshape array of size 29317 into known shapes
# File: dataset/faces_0\01\frame_00059_depth.bin, Buffer size: 117228 bytes
# Loaded data as float32 with length: 29307
# Could not reshape depth data: Could not reshape array of size 29307 into known shapes
# File: dataset/faces_0\01\frame_00060_depth.bin, Buffer size: 117238 bytes
# Could not interpret dataset/faces_0\01\frame_00060_depth.bin as float32.
# File: dataset/faces_0\01\frame_00061_depth.bin, Buffer size: 117396 bytes
# Loaded data as float32 with length: 29349
# Could not reshape depth data: Could not reshape array of size 29349 into known shapes
# File: dataset/faces_0\01\frame_00062_depth.bin, Buffer size: 117024 bytes
# Loaded data as float32 with length: 29256
# Could not reshape depth data: Could not reshape array of size 29256 into known shapes
# File: dataset/faces_0\01\frame_00063_depth.bin, Buffer size: 116728 bytes
# Loaded data as float32 with length: 29182
# Could not reshape depth data: Could not reshape array of size 29182 into known shapes
# File: dataset/faces_0\01\frame_00064_depth.bin, Buffer size: 116656 bytes
# Loaded data as float32 with length: 29164
# Could not reshape depth data: Could not reshape array of size 29164 into known shapes
# File: dataset/faces_0\01\frame_00065_depth.bin, Buffer size: 115786 bytes
# Could not interpret dataset/faces_0\01\frame_00065_depth.bin as float32.
# File: dataset/faces_0\01\frame_00066_depth.bin, Buffer size: 116528 bytes
# Loaded data as float32 with length: 29132
# Could not reshape depth data: Could not reshape array of size 29132 into known shapes
# File: dataset/faces_0\01\frame_00067_depth.bin, Buffer size: 116582 bytes
# Could not interpret dataset/faces_0\01\frame_00067_depth.bin as float32.
# File: dataset/faces_0\01\frame_00068_depth.bin, Buffer size: 116648 bytes
# Loaded data as float32 with length: 29162
# Could not reshape depth data: Could not reshape array of size 29162 into known shapes
# File: dataset/faces_0\01\frame_00069_depth.bin, Buffer size: 115490 bytes
# Could not interpret dataset/faces_0\01\frame_00069_depth.bin as float32.
# File: dataset/faces_0\01\frame_00070_depth.bin, Buffer size: 116424 bytes
# Loaded data as float32 with length: 29106
# Could not reshape depth data: Could not reshape array of size 29106 into known shapes
# File: dataset/faces_0\01\frame_00071_depth.bin, Buffer size: 116278 bytes
# Could not interpret dataset/faces_0\01\frame_00071_depth.bin as float32.
# File: dataset/faces_0\01\frame_00072_depth.bin, Buffer size: 116226 bytes
# Could not interpret dataset/faces_0\01\frame_00072_depth.bin as float32.
# File: dataset/faces_0\01\frame_00073_depth.bin, Buffer size: 116258 bytes
# Could not interpret dataset/faces_0\01\frame_00073_depth.bin as float32.
# File: dataset/faces_0\01\frame_00074_depth.bin, Buffer size: 116342 bytes
# Could not interpret dataset/faces_0\01\frame_00074_depth.bin as float32.
# File: dataset/faces_0\01\frame_00075_depth.bin, Buffer size: 116398 bytes
# Could not interpret dataset/faces_0\01\frame_00075_depth.bin as float32.
# File: dataset/faces_0\01\frame_00076_depth.bin, Buffer size: 116334 bytes
# Could not interpret dataset/faces_0\01\frame_00076_depth.bin as float32.
# File: dataset/faces_0\01\frame_00077_depth.bin, Buffer size: 115590 bytes
# Could not interpret dataset/faces_0\01\frame_00077_depth.bin as float32.
# File: dataset/faces_0\01\frame_00078_depth.bin, Buffer size: 116362 bytes
# Could not interpret dataset/faces_0\01\frame_00078_depth.bin as float32.
# File: dataset/faces_0\01\frame_00079_depth.bin, Buffer size: 115960 bytes
# Loaded data as float32 with length: 28990
# Could not reshape depth data: Could not reshape array of size 28990 into known shapes
# File: dataset/faces_0\01\frame_00080_depth.bin, Buffer size: 115606 bytes
# Could not interpret dataset/faces_0\01\frame_00080_depth.bin as float32.
# File: dataset/faces_0\01\frame_00081_depth.bin, Buffer size: 115412 bytes
# Loaded data as float32 with length: 28853
# Could not reshape depth data: Could not reshape array of size 28853 into known shapes
# File: dataset/faces_0\01\frame_00082_depth.bin, Buffer size: 116262 bytes
# Could not interpret dataset/faces_0\01\frame_00082_depth.bin as float32.
# File: dataset/faces_0\01\frame_00083_depth.bin, Buffer size: 115914 bytes
# Could not interpret dataset/faces_0\01\frame_00083_depth.bin as float32.
# File: dataset/faces_0\01\frame_00084_depth.bin, Buffer size: 116100 bytes
# Loaded data as float32 with length: 29025
# Could not reshape depth data: Could not reshape array of size 29025 into known shapes
# File: dataset/faces_0\01\frame_00085_depth.bin, Buffer size: 116154 bytes
# Could not interpret dataset/faces_0\01\frame_00085_depth.bin as float32.
# File: dataset/faces_0\01\frame_00086_depth.bin, Buffer size: 115896 bytes
# Loaded data as float32 with length: 28974
# Could not reshape depth data: Could not reshape array of size 28974 into known shapes
# File: dataset/faces_0\01\frame_00087_depth.bin, Buffer size: 115836 bytes
# Loaded data as float32 with length: 28959
# Could not reshape depth data: Could not reshape array of size 28959 into known shapes
# File: dataset/faces_0\01\frame_00088_depth.bin, Buffer size: 115302 bytes
# Could not interpret dataset/faces_0\01\frame_00088_depth.bin as float32.
# File: dataset/faces_0\01\frame_00089_depth.bin, Buffer size: 115782 bytes
# Could not interpret dataset/faces_0\01\frame_00089_depth.bin as float32.
# File: dataset/faces_0\01\frame_00090_depth.bin, Buffer size: 115848 bytes
# Loaded data as float32 with length: 28962
# Could not reshape depth data: Could not reshape array of size 28962 into known shapes
# File: dataset/faces_0\01\frame_00091_depth.bin, Buffer size: 115076 bytes
# Loaded data as float32 with length: 28769
# Could not reshape depth data: Could not reshape array of size 28769 into known shapes
# File: dataset/faces_0\01\frame_00092_depth.bin, Buffer size: 115496 bytes
# Loaded data as float32 with length: 28874
# Could not reshape depth data: Could not reshape array of size 28874 into known shapes
# File: dataset/faces_0\01\frame_00093_depth.bin, Buffer size: 115568 bytes
# Loaded data as float32 with length: 28892
# Could not reshape depth data: Could not reshape array of size 28892 into known shapes
# File: dataset/faces_0\01\frame_00094_depth.bin, Buffer size: 115930 bytes
# Could not interpret dataset/faces_0\01\frame_00094_depth.bin as float32.
# File: dataset/faces_0\01\frame_00095_depth.bin, Buffer size: 116242 bytes
# Could not interpret dataset/faces_0\01\frame_00095_depth.bin as float32.
# File: dataset/faces_0\01\frame_00096_depth.bin, Buffer size: 115876 bytes
# Loaded data as float32 with length: 28969
# Could not reshape depth data: Could not reshape array of size 28969 into known shapes
# File: dataset/faces_0\01\frame_00097_depth.bin, Buffer size: 115884 bytes
# Loaded data as float32 with length: 28971
# Could not reshape depth data: Could not reshape array of size 28971 into known shapes
# File: dataset/faces_0\01\frame_00098_depth.bin, Buffer size: 115600 bytes
# Loaded data as float32 with length: 28900
# Could not reshape depth data: Could not reshape array of size 28900 into known shapes
# File: dataset/faces_0\01\frame_00099_depth.bin, Buffer size: 115620 bytes
# Loaded data as float32 with length: 28905
# Could not reshape depth data: Could not reshape array of size 28905 into known shapes
# File: dataset/faces_0\01\frame_00100_depth.bin, Buffer size: 115630 bytes
# Could not interpret dataset/faces_0\01\frame_00100_depth.bin as float32.
# File: dataset/faces_0\01\frame_00101_depth.bin, Buffer size: 115536 bytes
# Loaded data as float32 with length: 28884
# Could not reshape depth data: Could not reshape array of size 28884 into known shapes
# File: dataset/faces_0\01\frame_00102_depth.bin, Buffer size: 115534 bytes
# Could not interpret dataset/faces_0\01\frame_00102_depth.bin as float32.
# File: dataset/faces_0\01\frame_00103_depth.bin, Buffer size: 115570 bytes
# Could not interpret dataset/faces_0\01\frame_00103_depth.bin as float32.
# File: dataset/faces_0\01\frame_00104_depth.bin, Buffer size: 115792 bytes
# Loaded data as float32 with length: 28948
# Could not reshape depth data: Could not reshape array of size 28948 into known shapes
# File: dataset/faces_0\01\frame_00105_depth.bin, Buffer size: 115656 bytes
# Loaded data as float32 with length: 28914
# Could not reshape depth data: Could not reshape array of size 28914 into known shapes
# File: dataset/faces_0\01\frame_00106_depth.bin, Buffer size: 114972 bytes
# Loaded data as float32 with length: 28743
# Could not reshape depth data: Could not reshape array of size 28743 into known shapes
# File: dataset/faces_0\01\frame_00107_depth.bin, Buffer size: 115012 bytes
# Loaded data as float32 with length: 28753
# Could not reshape depth data: Could not reshape array of size 28753 into known shapes
# File: dataset/faces_0\01\frame_00108_depth.bin, Buffer size: 115004 bytes
# Loaded data as float32 with length: 28751
# Could not reshape depth data: Could not reshape array of size 28751 into known shapes
# File: dataset/faces_0\01\frame_00109_depth.bin, Buffer size: 114820 bytes
# Loaded data as float32 with length: 28705
# Could not reshape depth data: Could not reshape array of size 28705 into known shapes
# File: dataset/faces_0\01\frame_00110_depth.bin, Buffer size: 114956 bytes
# Loaded data as float32 with length: 28739
# Could not reshape depth data: Could not reshape array of size 28739 into known shapes
# File: dataset/faces_0\01\frame_00111_depth.bin, Buffer size: 115610 bytes
# Could not interpret dataset/faces_0\01\frame_00111_depth.bin as float32.
# File: dataset/faces_0\01\frame_00112_depth.bin, Buffer size: 115738 bytes
# Could not interpret dataset/faces_0\01\frame_00112_depth.bin as float32.
# File: dataset/faces_0\01\frame_00113_depth.bin, Buffer size: 115830 bytes
# Could not interpret dataset/faces_0\01\frame_00113_depth.bin as float32.
# File: dataset/faces_0\01\frame_00114_depth.bin, Buffer size: 116286 bytes
# Could not interpret dataset/faces_0\01\frame_00114_depth.bin as float32.
# File: dataset/faces_0\01\frame_00115_depth.bin, Buffer size: 116470 bytes
# Could not interpret dataset/faces_0\01\frame_00115_depth.bin as float32.
# File: dataset/faces_0\01\frame_00116_depth.bin, Buffer size: 116722 bytes
# Could not interpret dataset/faces_0\01\frame_00116_depth.bin as float32.
# File: dataset/faces_0\01\frame_00117_depth.bin, Buffer size: 117110 bytes
# Could not interpret dataset/faces_0\01\frame_00117_depth.bin as float32.
# File: dataset/faces_0\01\frame_00118_depth.bin, Buffer size: 117504 bytes
# Loaded data as float32 with length: 29376
# Could not reshape depth data: Could not reshape array of size 29376 into known shapes
# File: dataset/faces_0\01\frame_00119_depth.bin, Buffer size: 117696 bytes
# Loaded data as float32 with length: 29424
# Could not reshape depth data: Could not reshape array of size 29424 into known shapes
# File: dataset/faces_0\01\frame_00120_depth.bin, Buffer size: 117640 bytes
# Loaded data as float32 with length: 29410
# Could not reshape depth data: Could not reshape array of size 29410 into known shapes
# File: dataset/faces_0\01\frame_00121_depth.bin, Buffer size: 117870 bytes
# Could not interpret dataset/faces_0\01\frame_00121_depth.bin as float32.
# File: dataset/faces_0\01\frame_00122_depth.bin, Buffer size: 118034 bytes
# Could not interpret dataset/faces_0\01\frame_00122_depth.bin as float32.
# File: dataset/faces_0\01\frame_00123_depth.bin, Buffer size: 118142 bytes
# Could not interpret dataset/faces_0\01\frame_00123_depth.bin as float32.
# File: dataset/faces_0\01\frame_00124_depth.bin, Buffer size: 118164 bytes
# Loaded data as float32 with length: 29541
# Could not reshape depth data: Could not reshape array of size 29541 into known shapes
# File: dataset/faces_0\01\frame_00125_depth.bin, Buffer size: 118492 bytes
# Loaded data as float32 with length: 29623
# Could not reshape depth data: Could not reshape array of size 29623 into known shapes
# File: dataset/faces_0\01\frame_00126_depth.bin, Buffer size: 118300 bytes
# Loaded data as float32 with length: 29575
# Could not reshape depth data: Could not reshape array of size 29575 into known shapes
# File: dataset/faces_0\01\frame_00127_depth.bin, Buffer size: 118560 bytes
# Loaded data as float32 with length: 29640
# Could not reshape depth data: Could not reshape array of size 29640 into known shapes
# File: dataset/faces_0\01\frame_00128_depth.bin, Buffer size: 118650 bytes
# Could not interpret dataset/faces_0\01\frame_00128_depth.bin as float32.
# File: dataset/faces_0\01\frame_00129_depth.bin, Buffer size: 118640 bytes
# Loaded data as float32 with length: 29660
# Could not reshape depth data: Could not reshape array of size 29660 into known shapes
# File: dataset/faces_0\01\frame_00130_depth.bin, Buffer size: 119004 bytes
# Loaded data as float32 with length: 29751
# Could not reshape depth data: Could not reshape array of size 29751 into known shapes
# File: dataset/faces_0\01\frame_00131_depth.bin, Buffer size: 119114 bytes
# Could not interpret dataset/faces_0\01\frame_00131_depth.bin as float32.
# File: dataset/faces_0\01\frame_00132_depth.bin, Buffer size: 119058 bytes
# Could not interpret dataset/faces_0\01\frame_00132_depth.bin as float32.
# File: dataset/faces_0\01\frame_00133_depth.bin, Buffer size: 119294 bytes
# Could not interpret dataset/faces_0\01\frame_00133_depth.bin as float32.
# File: dataset/faces_0\01\frame_00134_depth.bin, Buffer size: 119342 bytes
# Could not interpret dataset/faces_0\01\frame_00134_depth.bin as float32.
# File: dataset/faces_0\01\frame_00135_depth.bin, Buffer size: 119612 bytes
# Loaded data as float32 with length: 29903
# Could not reshape depth data: Could not reshape array of size 29903 into known shapes
# File: dataset/faces_0\01\frame_00136_depth.bin, Buffer size: 119382 bytes
# Could not interpret dataset/faces_0\01\frame_00136_depth.bin as float32.
# File: dataset/faces_0\01\frame_00137_depth.bin, Buffer size: 119282 bytes
# Could not interpret dataset/faces_0\01\frame_00137_depth.bin as float32.
# File: dataset/faces_0\01\frame_00138_depth.bin, Buffer size: 119924 bytes
# Loaded data as float32 with length: 29981
# Could not reshape depth data: Could not reshape array of size 29981 into known shapes
# File: dataset/faces_0\01\frame_00139_depth.bin, Buffer size: 119764 bytes
# Loaded data as float32 with length: 29941
# Could not reshape depth data: Could not reshape array of size 29941 into known shapes
# File: dataset/faces_0\01\frame_00140_depth.bin, Buffer size: 119768 bytes
# Loaded data as float32 with length: 29942
# Could not reshape depth data: Could not reshape array of size 29942 into known shapes
# File: dataset/faces_0\01\frame_00141_depth.bin, Buffer size: 119948 bytes
# Loaded data as float32 with length: 29987
# Could not reshape depth data: Could not reshape array of size 29987 into known shapes
# File: dataset/faces_0\01\frame_00142_depth.bin, Buffer size: 119940 bytes
# Loaded data as float32 with length: 29985
# Could not reshape depth data: Could not reshape array of size 29985 into known shapes
# File: dataset/faces_0\01\frame_00143_depth.bin, Buffer size: 119840 bytes
# Loaded data as float32 with length: 29960
# Could not reshape depth data: Could not reshape array of size 29960 into known shapes
# File: dataset/faces_0\01\frame_00144_depth.bin, Buffer size: 119788 bytes
# Loaded data as float32 with length: 29947
# Could not reshape depth data: Could not reshape array of size 29947 into known shapes
# File: dataset/faces_0\01\frame_00145_depth.bin, Buffer size: 119880 bytes
# Loaded data as float32 with length: 29970
# Could not reshape depth data: Could not reshape array of size 29970 into known shapes
# File: dataset/faces_0\01\frame_00146_depth.bin, Buffer size: 119820 bytes
# Loaded data as float32 with length: 29955
# Could not reshape depth data: Could not reshape array of size 29955 into known shapes
# File: dataset/faces_0\01\frame_00147_depth.bin, Buffer size: 119764 bytes
# Loaded data as float32 with length: 29941
# Could not reshape depth data: Could not reshape array of size 29941 into known shapes
# File: dataset/faces_0\01\frame_00148_depth.bin, Buffer size: 119624 bytes
# Loaded data as float32 with length: 29906
# Could not reshape depth data: Could not reshape array of size 29906 into known shapes
# File: dataset/faces_0\01\frame_00149_depth.bin, Buffer size: 119212 bytes
# Loaded data as float32 with length: 29803
# Could not reshape depth data: Could not reshape array of size 29803 into known shapes
# File: dataset/faces_0\01\frame_00150_depth.bin, Buffer size: 119412 bytes
# Loaded data as float32 with length: 29853
# Could not reshape depth data: Could not reshape array of size 29853 into known shapes
# File: dataset/faces_0\01\frame_00151_depth.bin, Buffer size: 119152 bytes
# Loaded data as float32 with length: 29788
# Could not reshape depth data: Could not reshape array of size 29788 into known shapes
# File: dataset/faces_0\01\frame_00152_depth.bin, Buffer size: 119004 bytes
# Loaded data as float32 with length: 29751
# Could not reshape depth data: Could not reshape array of size 29751 into known shapes
# File: dataset/faces_0\01\frame_00153_depth.bin, Buffer size: 118590 bytes
# Could not interpret dataset/faces_0\01\frame_00153_depth.bin as float32.
# File: dataset/faces_0\01\frame_00154_depth.bin, Buffer size: 118696 bytes
# Loaded data as float32 with length: 29674
# Could not reshape depth data: Could not reshape array of size 29674 into known shapes
# File: dataset/faces_0\01\frame_00155_depth.bin, Buffer size: 118358 bytes
# Could not interpret dataset/faces_0\01\frame_00155_depth.bin as float32.
# File: dataset/faces_0\01\frame_00156_depth.bin, Buffer size: 118280 bytes
# Loaded data as float32 with length: 29570
# Could not reshape depth data: Could not reshape array of size 29570 into known shapes
# File: dataset/faces_0\01\frame_00157_depth.bin, Buffer size: 118444 bytes
# Loaded data as float32 with length: 29611
# Could not reshape depth data: Could not reshape array of size 29611 into known shapes
# File: dataset/faces_0\01\frame_00158_depth.bin, Buffer size: 118078 bytes
# Could not interpret dataset/faces_0\01\frame_00158_depth.bin as float32.
# File: dataset/faces_0\01\frame_00159_depth.bin, Buffer size: 118252 bytes
# Loaded data as float32 with length: 29563
# Could not reshape depth data: Could not reshape array of size 29563 into known shapes
# File: dataset/faces_0\01\frame_00160_depth.bin, Buffer size: 118038 bytes
# Could not interpret dataset/faces_0\01\frame_00160_depth.bin as float32.
# File: dataset/faces_0\01\frame_00161_depth.bin, Buffer size: 116390 bytes
# Could not interpret dataset/faces_0\01\frame_00161_depth.bin as float32.
# File: dataset/faces_0\01\frame_00162_depth.bin, Buffer size: 116806 bytes
# Could not interpret dataset/faces_0\01\frame_00162_depth.bin as float32.
# File: dataset/faces_0\01\frame_00163_depth.bin, Buffer size: 116812 bytes
# Loaded data as float32 with length: 29203
# Could not reshape depth data: Could not reshape array of size 29203 into known shapes
# File: dataset/faces_0\01\frame_00164_depth.bin, Buffer size: 116954 bytes
# Could not interpret dataset/faces_0\01\frame_00164_depth.bin as float32.
# File: dataset/faces_0\01\frame_00165_depth.bin, Buffer size: 116366 bytes
# Could not interpret dataset/faces_0\01\frame_00165_depth.bin as float32.
# File: dataset/faces_0\01\frame_00166_depth.bin, Buffer size: 116802 bytes
# Could not interpret dataset/faces_0\01\frame_00166_depth.bin as float32.
# File: dataset/faces_0\01\frame_00167_depth.bin, Buffer size: 116080 bytes
# Loaded data as float32 with length: 29020
# Could not reshape depth data: Could not reshape array of size 29020 into known shapes
# File: dataset/faces_0\01\frame_00168_depth.bin, Buffer size: 116534 bytes
# Could not interpret dataset/faces_0\01\frame_00168_depth.bin as float32.
# File: dataset/faces_0\01\frame_00169_depth.bin, Buffer size: 116500 bytes
# Loaded data as float32 with length: 29125
# Could not reshape depth data: Could not reshape array of size 29125 into known shapes
# File: dataset/faces_0\01\frame_00170_depth.bin, Buffer size: 116488 bytes
# Loaded data as float32 with length: 29122
# Could not reshape depth data: Could not reshape array of size 29122 into known shapes
# File: dataset/faces_0\01\frame_00171_depth.bin, Buffer size: 116630 bytes
# Could not interpret dataset/faces_0\01\frame_00171_depth.bin as float32.
# File: dataset/faces_0\01\frame_00172_depth.bin, Buffer size: 117016 bytes
# Loaded data as float32 with length: 29254
# Could not reshape depth data: Could not reshape array of size 29254 into known shapes
# File: dataset/faces_0\01\frame_00173_depth.bin, Buffer size: 116284 bytes
# Loaded data as float32 with length: 29071
# Could not reshape depth data: Could not reshape array of size 29071 into known shapes
# File: dataset/faces_0\01\frame_00174_depth.bin, Buffer size: 115796 bytes
# Loaded data as float32 with length: 28949
# Could not reshape depth data: Could not reshape array of size 28949 into known shapes
# File: dataset/faces_0\01\frame_00175_depth.bin, Buffer size: 115950 bytes
# Could not interpret dataset/faces_0\01\frame_00175_depth.bin as float32.
# File: dataset/faces_0\01\frame_00176_depth.bin, Buffer size: 116422 bytes
# Could not interpret dataset/faces_0\01\frame_00176_depth.bin as float32.
# File: dataset/faces_0\01\frame_00177_depth.bin, Buffer size: 116900 bytes
# Loaded data as float32 with length: 29225
# Could not reshape depth data: Could not reshape array of size 29225 into known shapes
# File: dataset/faces_0\01\frame_00178_depth.bin, Buffer size: 116672 bytes
# Loaded data as float32 with length: 29168
# Could not reshape depth data: Could not reshape array of size 29168 into known shapes
# File: dataset/faces_0\01\frame_00179_depth.bin, Buffer size: 116818 bytes
# Could not interpret dataset/faces_0\01\frame_00179_depth.bin as float32.
# File: dataset/faces_0\01\frame_00180_depth.bin, Buffer size: 116678 bytes
# Could not interpret dataset/faces_0\01\frame_00180_depth.bin as float32.
# File: dataset/faces_0\01\frame_00181_depth.bin, Buffer size: 116316 bytes
# Loaded data as float32 with length: 29079
# Could not reshape depth data: Could not reshape array of size 29079 into known shapes
# File: dataset/faces_0\01\frame_00182_depth.bin, Buffer size: 116740 bytes
# Loaded data as float32 with length: 29185
# Could not reshape depth data: Could not reshape array of size 29185 into known shapes
# File: dataset/faces_0\01\frame_00183_depth.bin, Buffer size: 116530 bytes
# Could not interpret dataset/faces_0\01\frame_00183_depth.bin as float32.
# File: dataset/faces_0\01\frame_00184_depth.bin, Buffer size: 116854 bytes
# Could not interpret dataset/faces_0\01\frame_00184_depth.bin as float32.
# File: dataset/faces_0\01\frame_00185_depth.bin, Buffer size: 116506 bytes
# Could not interpret dataset/faces_0\01\frame_00185_depth.bin as float32.
# File: dataset/faces_0\01\frame_00186_depth.bin, Buffer size: 116798 bytes
# Could not interpret dataset/faces_0\01\frame_00186_depth.bin as float32.
# File: dataset/faces_0\01\frame_00187_depth.bin, Buffer size: 117402 bytes
# Could not interpret dataset/faces_0\01\frame_00187_depth.bin as float32.
# File: dataset/faces_0\01\frame_00188_depth.bin, Buffer size: 117020 bytes
# Loaded data as float32 with length: 29255
# Could not reshape depth data: Could not reshape array of size 29255 into known shapes
# File: dataset/faces_0\01\frame_00189_depth.bin, Buffer size: 117750 bytes
# Could not interpret dataset/faces_0\01\frame_00189_depth.bin as float32.
# File: dataset/faces_0\01\frame_00190_depth.bin, Buffer size: 118384 bytes
# Loaded data as float32 with length: 29596
# Could not reshape depth data: Could not reshape array of size 29596 into known shapes
# File: dataset/faces_0\01\frame_00191_depth.bin, Buffer size: 118890 bytes
# Could not interpret dataset/faces_0\01\frame_00191_depth.bin as float32.
# File: dataset/faces_0\01\frame_00192_depth.bin, Buffer size: 118502 bytes
# Could not interpret dataset/faces_0\01\frame_00192_depth.bin as float32.
# File: dataset/faces_0\01\frame_00193_depth.bin, Buffer size: 119280 bytes
# Loaded data as float32 with length: 29820
# Could not reshape depth data: Could not reshape array of size 29820 into known shapes
# File: dataset/faces_0\01\frame_00194_depth.bin, Buffer size: 119416 bytes
# Loaded data as float32 with length: 29854
# Could not reshape depth data: Could not reshape array of size 29854 into known shapes
# File: dataset/faces_0\01\frame_00195_depth.bin, Buffer size: 119428 bytes
# Loaded data as float32 with length: 29857
# Could not reshape depth data: Could not reshape array of size 29857 into known shapes
# File: dataset/faces_0\01\frame_00196_depth.bin, Buffer size: 119826 bytes
# Could not interpret dataset/faces_0\01\frame_00196_depth.bin as float32.
# File: dataset/faces_0\01\frame_00197_depth.bin, Buffer size: 119824 bytes
# Loaded data as float32 with length: 29956
# Could not reshape depth data: Could not reshape array of size 29956 into known shapes
# File: dataset/faces_0\01\frame_00198_depth.bin, Buffer size: 119998 bytes
# Could not interpret dataset/faces_0\01\frame_00198_depth.bin as float32.
# File: dataset/faces_0\01\frame_00199_depth.bin, Buffer size: 120356 bytes
# Loaded data as float32 with length: 30089
# Could not reshape depth data: Could not reshape array of size 30089 into known shapes
# File: dataset/faces_0\01\frame_00200_depth.bin, Buffer size: 120738 bytes
# Could not interpret dataset/faces_0\01\frame_00200_depth.bin as float32.
# File: dataset/faces_0\01\frame_00201_depth.bin, Buffer size: 121082 bytes
# Could not interpret dataset/faces_0\01\frame_00201_depth.bin as float32.
# File: dataset/faces_0\01\frame_00202_depth.bin, Buffer size: 121236 bytes
# Loaded data as float32 with length: 30309
# Could not reshape depth data: Could not reshape array of size 30309 into known shapes
# File: dataset/faces_0\01\frame_00203_depth.bin, Buffer size: 121138 bytes
# Could not interpret dataset/faces_0\01\frame_00203_depth.bin as float32.
# File: dataset/faces_0\01\frame_00204_depth.bin, Buffer size: 121316 bytes
# Loaded data as float32 with length: 30329
# Could not reshape depth data: Could not reshape array of size 30329 into known shapes
# File: dataset/faces_0\01\frame_00205_depth.bin, Buffer size: 121280 bytes
# Loaded data as float32 with length: 30320
# Could not reshape depth data: Could not reshape array of size 30320 into known shapes
# File: dataset/faces_0\01\frame_00206_depth.bin, Buffer size: 120754 bytes
# Could not interpret dataset/faces_0\01\frame_00206_depth.bin as float32.
# File: dataset/faces_0\01\frame_00207_depth.bin, Buffer size: 121458 bytes
# Could not interpret dataset/faces_0\01\frame_00207_depth.bin as float32.
# File: dataset/faces_0\01\frame_00208_depth.bin, Buffer size: 122054 bytes
# Could not interpret dataset/faces_0\01\frame_00208_depth.bin as float32.
# File: dataset/faces_0\01\frame_00209_depth.bin, Buffer size: 121562 bytes
# Could not interpret dataset/faces_0\01\frame_00209_depth.bin as float32.
# File: dataset/faces_0\01\frame_00210_depth.bin, Buffer size: 121088 bytes
# Loaded data as float32 with length: 30272
# Could not reshape depth data: Could not reshape array of size 30272 into known shapes
# File: dataset/faces_0\01\frame_00211_depth.bin, Buffer size: 121242 bytes
# Could not interpret dataset/faces_0\01\frame_00211_depth.bin as float32.
# File: dataset/faces_0\01\frame_00212_depth.bin, Buffer size: 121384 bytes
# Loaded data as float32 with length: 30346
# Could not reshape depth data: Could not reshape array of size 30346 into known shapes
# File: dataset/faces_0\01\frame_00213_depth.bin, Buffer size: 121646 bytes
# Could not interpret dataset/faces_0\01\frame_00213_depth.bin as float32.
# File: dataset/faces_0\01\frame_00214_depth.bin, Buffer size: 121782 bytes
# Could not interpret dataset/faces_0\01\frame_00214_depth.bin as float32.
# File: dataset/faces_0\01\frame_00215_depth.bin, Buffer size: 121750 bytes
# Could not interpret dataset/faces_0\01\frame_00215_depth.bin as float32.
# File: dataset/faces_0\01\frame_00216_depth.bin, Buffer size: 121414 bytes
# Could not interpret dataset/faces_0\01\frame_00216_depth.bin as float32.
# File: dataset/faces_0\01\frame_00217_depth.bin, Buffer size: 121660 bytes
# Loaded data as float32 with length: 30415
# Could not reshape depth data: Could not reshape array of size 30415 into known shapes
# File: dataset/faces_0\01\frame_00218_depth.bin, Buffer size: 121862 bytes
# Could not interpret dataset/faces_0\01\frame_00218_depth.bin as float32.
# File: dataset/faces_0\01\frame_00219_depth.bin, Buffer size: 121656 bytes
# Loaded data as float32 with length: 30414
# Could not reshape depth data: Could not reshape array of size 30414 into known shapes
# File: dataset/faces_0\01\frame_00220_depth.bin, Buffer size: 122124 bytes
# Loaded data as float32 with length: 30531
# Could not reshape depth data: Could not reshape array of size 30531 into known shapes
# File: dataset/faces_0\01\frame_00221_depth.bin, Buffer size: 121808 bytes
# Loaded data as float32 with length: 30452
# Could not reshape depth data: Could not reshape array of size 30452 into known shapes
# File: dataset/faces_0\01\frame_00222_depth.bin, Buffer size: 121540 bytes
# Loaded data as float32 with length: 30385
# Could not reshape depth data: Could not reshape array of size 30385 into known shapes
# File: dataset/faces_0\01\frame_00223_depth.bin, Buffer size: 122466 bytes
# Could not interpret dataset/faces_0\01\frame_00223_depth.bin as float32.
# File: dataset/faces_0\01\frame_00224_depth.bin, Buffer size: 122578 bytes
# Could not interpret dataset/faces_0\01\frame_00224_depth.bin as float32.
# File: dataset/faces_0\01\frame_00225_depth.bin, Buffer size: 122110 bytes
# Could not interpret dataset/faces_0\01\frame_00225_depth.bin as float32.
# File: dataset/faces_0\01\frame_00226_depth.bin, Buffer size: 122158 bytes
# Could not interpret dataset/faces_0\01\frame_00226_depth.bin as float32.
# File: dataset/faces_0\01\frame_00227_depth.bin, Buffer size: 122988 bytes
# Loaded data as float32 with length: 30747
# Could not reshape depth data: Could not reshape array of size 30747 into known shapes
# File: dataset/faces_0\01\frame_00228_depth.bin, Buffer size: 122572 bytes
# Loaded data as float32 with length: 30643
# Could not reshape depth data: Could not reshape array of size 30643 into known shapes
# File: dataset/faces_0\01\frame_00229_depth.bin, Buffer size: 122150 bytes
# Could not interpret dataset/faces_0\01\frame_00229_depth.bin as float32.
# File: dataset/faces_0\01\frame_00230_depth.bin, Buffer size: 122544 bytes
# Loaded data as float32 with length: 30636
# Could not reshape depth data: Could not reshape array of size 30636 into known shapes
# File: dataset/faces_0\01\frame_00231_depth.bin, Buffer size: 122384 bytes
# Loaded data as float32 with length: 30596
# Could not reshape depth data: Could not reshape array of size 30596 into known shapes
# File: dataset/faces_0\01\frame_00232_depth.bin, Buffer size: 122336 bytes
# Loaded data as float32 with length: 30584
# Could not reshape depth data: Could not reshape array of size 30584 into known shapes
# File: dataset/faces_0\01\frame_00233_depth.bin, Buffer size: 122438 bytes
# Could not interpret dataset/faces_0\01\frame_00233_depth.bin as float32.
# File: dataset/faces_0\01\frame_00234_depth.bin, Buffer size: 122450 bytes
# Could not interpret dataset/faces_0\01\frame_00234_depth.bin as float32.
# File: dataset/faces_0\01\frame_00235_depth.bin, Buffer size: 121996 bytes
# Loaded data as float32 with length: 30499
# Could not reshape depth data: Could not reshape array of size 30499 into known shapes
# File: dataset/faces_0\01\frame_00236_depth.bin, Buffer size: 121816 bytes
# Loaded data as float32 with length: 30454
# Could not reshape depth data: Could not reshape array of size 30454 into known shapes
# File: dataset/faces_0\01\frame_00237_depth.bin, Buffer size: 122158 bytes
# Could not interpret dataset/faces_0\01\frame_00237_depth.bin as float32.
# File: dataset/faces_0\01\frame_00238_depth.bin, Buffer size: 121828 bytes
# Loaded data as float32 with length: 30457
# Could not reshape depth data: Could not reshape array of size 30457 into known shapes
# File: dataset/faces_0\01\frame_00239_depth.bin, Buffer size: 121600 bytes
# Loaded data as float32 with length: 30400
# Could not reshape depth data: Could not reshape array of size 30400 into known shapes
# File: dataset/faces_0\01\frame_00240_depth.bin, Buffer size: 121428 bytes
# Loaded data as float32 with length: 30357
# Could not reshape depth data: Could not reshape array of size 30357 into known shapes
# File: dataset/faces_0\01\frame_00241_depth.bin, Buffer size: 121182 bytes
# Could not interpret dataset/faces_0\01\frame_00241_depth.bin as float32.
# File: dataset/faces_0\01\frame_00242_depth.bin, Buffer size: 121148 bytes
# Loaded data as float32 with length: 30287
# Could not reshape depth data: Could not reshape array of size 30287 into known shapes
# File: dataset/faces_0\01\frame_00243_depth.bin, Buffer size: 120934 bytes
# Could not interpret dataset/faces_0\01\frame_00243_depth.bin as float32.
# File: dataset/faces_0\01\frame_00244_depth.bin, Buffer size: 120854 bytes
# Could not interpret dataset/faces_0\01\frame_00244_depth.bin as float32.
# File: dataset/faces_0\01\frame_00245_depth.bin, Buffer size: 120596 bytes
# Loaded data as float32 with length: 30149
# Could not reshape depth data: Could not reshape array of size 30149 into known shapes
# File: dataset/faces_0\01\frame_00246_depth.bin, Buffer size: 120728 bytes
# Loaded data as float32 with length: 30182
# Could not reshape depth data: Could not reshape array of size 30182 into known shapes
# File: dataset/faces_0\01\frame_00247_depth.bin, Buffer size: 120312 bytes
# Loaded data as float32 with length: 30078
# Could not reshape depth data: Could not reshape array of size 30078 into known shapes
# File: dataset/faces_0\01\frame_00248_depth.bin, Buffer size: 119972 bytes
# Loaded data as float32 with length: 29993
# Could not reshape depth data: Could not reshape array of size 29993 into known shapes
# File: dataset/faces_0\01\frame_00249_depth.bin, Buffer size: 119836 bytes
# Loaded data as float32 with length: 29959
# Could not reshape depth data: Could not reshape array of size 29959 into known shapes
# File: dataset/faces_0\01\frame_00250_depth.bin, Buffer size: 120084 bytes
# Loaded data as float32 with length: 30021
# Could not reshape depth data: Could not reshape array of size 30021 into known shapes
# File: dataset/faces_0\01\frame_00251_depth.bin, Buffer size: 119610 bytes
# Could not interpret dataset/faces_0\01\frame_00251_depth.bin as float32.
# File: dataset/faces_0\01\frame_00252_depth.bin, Buffer size: 119084 bytes
# Loaded data as float32 with length: 29771
# Could not reshape depth data: Could not reshape array of size 29771 into known shapes
# File: dataset/faces_0\01\frame_00253_depth.bin, Buffer size: 118146 bytes
# Could not interpret dataset/faces_0\01\frame_00253_depth.bin as float32.
# File: dataset/faces_0\01\frame_00254_depth.bin, Buffer size: 118286 bytes
# Could not interpret dataset/faces_0\01\frame_00254_depth.bin as float32.
# File: dataset/faces_0\01\frame_00255_depth.bin, Buffer size: 118018 bytes
# Could not interpret dataset/faces_0\01\frame_00255_depth.bin as float32.
# File: dataset/faces_0\01\frame_00256_depth.bin, Buffer size: 117710 bytes
# Could not interpret dataset/faces_0\01\frame_00256_depth.bin as float32.
# File: dataset/faces_0\01\frame_00257_depth.bin, Buffer size: 117772 bytes
# Loaded data as float32 with length: 29443
# Could not reshape depth data: Could not reshape array of size 29443 into known shapes
# File: dataset/faces_0\01\frame_00258_depth.bin, Buffer size: 117596 bytes
# Loaded data as float32 with length: 29399
# Could not reshape depth data: Could not reshape array of size 29399 into known shapes
# File: dataset/faces_0\01\frame_00259_depth.bin, Buffer size: 117156 bytes
# Loaded data as float32 with length: 29289
# Could not reshape depth data: Could not reshape array of size 29289 into known shapes
# File: dataset/faces_0\01\frame_00260_depth.bin, Buffer size: 117254 bytes
# Could not interpret dataset/faces_0\01\frame_00260_depth.bin as float32.
# File: dataset/faces_0\01\frame_00261_depth.bin, Buffer size: 117118 bytes
# Could not interpret dataset/faces_0\01\frame_00261_depth.bin as float32.
# File: dataset/faces_0\01\frame_00262_depth.bin, Buffer size: 116868 bytes
# Loaded data as float32 with length: 29217
# Could not reshape depth data: Could not reshape array of size 29217 into known shapes
# File: dataset/faces_0\01\frame_00263_depth.bin, Buffer size: 116540 bytes
# Loaded data as float32 with length: 29135
# Could not reshape depth data: Could not reshape array of size 29135 into known shapes
# File: dataset/faces_0\01\frame_00264_depth.bin, Buffer size: 116836 bytes
# Loaded data as float32 with length: 29209
# Could not reshape depth data: Could not reshape array of size 29209 into known shapes
# File: dataset/faces_0\01\frame_00265_depth.bin, Buffer size: 116002 bytes
# Could not interpret dataset/faces_0\01\frame_00265_depth.bin as float32.
# File: dataset/faces_0\01\frame_00266_depth.bin, Buffer size: 117042 bytes
# Could not interpret dataset/faces_0\01\frame_00266_depth.bin as float32.
# File: dataset/faces_0\01\frame_00267_depth.bin, Buffer size: 116378 bytes
# Could not interpret dataset/faces_0\01\frame_00267_depth.bin as float32.
# File: dataset/faces_0\01\frame_00268_depth.bin, Buffer size: 116654 bytes
# Could not interpret dataset/faces_0\01\frame_00268_depth.bin as float32.
# File: dataset/faces_0\01\frame_00269_depth.bin, Buffer size: 116658 bytes
# Could not interpret dataset/faces_0\01\frame_00269_depth.bin as float32.
# File: dataset/faces_0\01\frame_00270_depth.bin, Buffer size: 116682 bytes
# Could not interpret dataset/faces_0\01\frame_00270_depth.bin as float32.
# File: dataset/faces_0\01\frame_00271_depth.bin, Buffer size: 117008 bytes
# Loaded data as float32 with length: 29252
# Could not reshape depth data: Could not reshape array of size 29252 into known shapes
# File: dataset/faces_0\01\frame_00272_depth.bin, Buffer size: 116508 bytes
# Loaded data as float32 with length: 29127
# Could not reshape depth data: Could not reshape array of size 29127 into known shapes
# File: dataset/faces_0\01\frame_00273_depth.bin, Buffer size: 116272 bytes
# Loaded data as float32 with length: 29068
# Could not reshape depth data: Could not reshape array of size 29068 into known shapes
# File: dataset/faces_0\01\frame_00274_depth.bin, Buffer size: 117220 bytes
# Loaded data as float32 with length: 29305
# Could not reshape depth data: Could not reshape array of size 29305 into known shapes
# File: dataset/faces_0\01\frame_00275_depth.bin, Buffer size: 117812 bytes
# ...
# File: dataset/faces_0\01\frame_00378_depth.bin, Buffer size: 118676 bytes
# Loaded data as float32 with length: 29669
# Could not reshape depth data: Could not reshape array of size 29669 into known shapes
# File: dataset/faces_0\01\frame_00379_depth.bin, Buffer size: 119274 bytes
# Could not interpret dataset/faces_0\01\frame_00379_depth.bin as float32.
# File: dataset/faces_0\01\frame_00380_depth.bin, Buffer size: 119266 bytes
# Could not interpret dataset/faces_0\01\frame_00380_depth.bin as float32.
# File: dataset/faces_0\01\frame_00381_depth.bin, Buffer size: 119444 bytes
# Loaded data as float32 with length: 29861
# Could not reshape depth data: Could not reshape array of size 29861 into known shapes
# File: dataset/faces_0\01\frame_00382_depth.bin, Buffer size: 119880 bytes
# Loaded data as float32 with length: 29970
# Could not reshape depth data: Could not reshape array of size 29970 into known shapes
# File: dataset/faces_0\01\frame_00383_depth.bin, Buffer size: 120632 bytes
# Loaded data as float32 with length: 30158
# Could not reshape depth data: Could not reshape array of size 30158 into known shapes
# File: dataset/faces_0\01\frame_00384_depth.bin, Buffer size: 120998 bytes
# Could not interpret dataset/faces_0\01\frame_00384_depth.bin as float32.
# File: dataset/faces_0\01\frame_00385_depth.bin, Buffer size: 120106 bytes
# Could not interpret dataset/faces_0\01\frame_00385_depth.bin as float32.
# File: dataset/faces_0\01\frame_00386_depth.bin, Buffer size: 121844 bytes
# Loaded data as float32 with length: 30461
# Could not reshape depth data: Could not reshape array of size 30461 into known shapes
# File: dataset/faces_0\01\frame_00387_depth.bin, Buffer size: 121996 bytes
# Loaded data as float32 with length: 30499
# Could not reshape depth data: Could not reshape array of size 30499 into known shapes
# File: dataset/faces_0\01\frame_00388_depth.bin, Buffer size: 122314 bytes
# Could not interpret dataset/faces_0\01\frame_00388_depth.bin as float32.
# File: dataset/faces_0\01\frame_00389_depth.bin, Buffer size: 121884 bytes
# Loaded data as float32 with length: 30471
# Could not reshape depth data: Could not reshape array of size 30471 into known shapes
# File: dataset/faces_0\01\frame_00390_depth.bin, Buffer size: 122676 bytes
# Loaded data as float32 with length: 30669
# Could not reshape depth data: Could not reshape array of size 30669 into known shapes
# File: dataset/faces_0\01\frame_00391_depth.bin, Buffer size: 123042 bytes
# Could not interpret dataset/faces_0\01\frame_00391_depth.bin as float32.
# File: dataset/faces_0\01\frame_00392_depth.bin, Buffer size: 122858 bytes
# Could not interpret dataset/faces_0\01\frame_00392_depth.bin as float32.
# File: dataset/faces_0\01\frame_00393_depth.bin, Buffer size: 123456 bytes
# Loaded data as float32 with length: 30864
# Could not reshape depth data: Could not reshape array of size 30864 into known shapes
# File: dataset/faces_0\01\frame_00394_depth.bin, Buffer size: 123690 bytes
# Could not interpret dataset/faces_0\01\frame_00394_depth.bin as float32.
# File: dataset/faces_0\01\frame_00395_depth.bin, Buffer size: 123486 bytes
# Could not interpret dataset/faces_0\01\frame_00395_depth.bin as float32.
# File: dataset/faces_0\01\frame_00396_depth.bin, Buffer size: 123380 bytes
# Loaded data as float32 with length: 30845
# Could not reshape depth data: Could not reshape array of size 30845 into known shapes
# File: dataset/faces_0\01\frame_00397_depth.bin, Buffer size: 123520 bytes
# Loaded data as float32 with length: 30880
# Could not reshape depth data: Could not reshape array of size 30880 into known shapes
# File: dataset/faces_0\01\frame_00398_depth.bin, Buffer size: 123868 bytes
# Loaded data as float32 with length: 30967
# Could not reshape depth data: Could not reshape array of size 30967 into known shapes
# File: dataset/faces_0\01\frame_00399_depth.bin, Buffer size: 123224 bytes
# Loaded data as float32 with length: 30806
# Could not reshape depth data: Could not reshape array of size 30806 into known shapes
# File: dataset/faces_0\01\frame_00400_depth.bin, Buffer size: 123538 bytes
# Could not interpret dataset/faces_0\01\frame_00400_depth.bin as float32.
# File: dataset/faces_0\01\frame_00401_depth.bin, Buffer size: 123624 bytes
# Loaded data as float32 with length: 30906
# Could not reshape depth data: Could not reshape array of size 30906 into known shapes
# File: dataset/faces_0\01\frame_00402_depth.bin, Buffer size: 124170 bytes
# Could not interpret dataset/faces_0\01\frame_00402_depth.bin as float32.
# File: dataset/faces_0\01\frame_00403_depth.bin, Buffer size: 124098 bytes
# Could not interpret dataset/faces_0\01\frame_00403_depth.bin as float32.
# File: dataset/faces_0\01\frame_00404_depth.bin, Buffer size: 124280 bytes
# Loaded data as float32 with length: 31070
# Could not reshape depth data: Could not reshape array of size 31070 into known shapes
# File: dataset/faces_0\01\frame_00405_depth.bin, Buffer size: 124036 bytes
# Loaded data as float32 with length: 31009
# Could not reshape depth data: Could not reshape array of size 31009 into known shapes
# File: dataset/faces_0\01\frame_00406_depth.bin, Buffer size: 124036 bytes
# Loaded data as float32 with length: 31009
# Could not reshape depth data: Could not reshape array of size 31009 into known shapes
# File: dataset/faces_0\01\frame_00407_depth.bin, Buffer size: 124140 bytes
# Loaded data as float32 with length: 31035
# Could not reshape depth data: Could not reshape array of size 31035 into known shapes
# File: dataset/faces_0\01\frame_00408_depth.bin, Buffer size: 124018 bytes
# Could not interpret dataset/faces_0\01\frame_00408_depth.bin as float32.
# File: dataset/faces_0\01\frame_00409_depth.bin, Buffer size: 124178 bytes
# Could not interpret dataset/faces_0\01\frame_00409_depth.bin as float32.
# File: dataset/faces_0\01\frame_00410_depth.bin, Buffer size: 124296 bytes
# Loaded data as float32 with length: 31074
# Could not reshape depth data: Could not reshape array of size 31074 into known shapes
# File: dataset/faces_0\01\frame_00411_depth.bin, Buffer size: 124376 bytes
# Loaded data as float32 with length: 31094
# Could not reshape depth data: Could not reshape array of size 31094 into known shapes
# File: dataset/faces_0\01\frame_00412_depth.bin, Buffer size: 124186 bytes
# Could not interpret dataset/faces_0\01\frame_00412_depth.bin as float32.
# File: dataset/faces_0\01\frame_00413_depth.bin, Buffer size: 124414 bytes
# Could not interpret dataset/faces_0\01\frame_00413_depth.bin as float32.
# File: dataset/faces_0\01\frame_00414_depth.bin, Buffer size: 123922 bytes
# Could not interpret dataset/faces_0\01\frame_00414_depth.bin as float32.
# File: dataset/faces_0\01\frame_00415_depth.bin, Buffer size: 124318 bytes
# Could not interpret dataset/faces_0\01\frame_00415_depth.bin as float32.
# File: dataset/faces_0\01\frame_00416_depth.bin, Buffer size: 124070 bytes
# Could not interpret dataset/faces_0\01\frame_00416_depth.bin as float32.
# File: dataset/faces_0\01\frame_00417_depth.bin, Buffer size: 124104 bytes
# Loaded data as float32 with length: 31026
# Could not reshape depth data: Could not reshape array of size 31026 into known shapes
# File: dataset/faces_0\01\frame_00418_depth.bin, Buffer size: 124184 bytes
# Loaded data as float32 with length: 31046
# Could not reshape depth data: Could not reshape array of size 31046 into known shapes
# File: dataset/faces_0\01\frame_00419_depth.bin, Buffer size: 124218 bytes
# Could not interpret dataset/faces_0\01\frame_00419_depth.bin as float32.
# File: dataset/faces_0\01\frame_00420_depth.bin, Buffer size: 124318 bytes
# Could not interpret dataset/faces_0\01\frame_00420_depth.bin as float32.
# File: dataset/faces_0\01\frame_00421_depth.bin, Buffer size: 124620 bytes
# Loaded data as float32 with length: 31155
# Could not reshape depth data: Could not reshape array of size 31155 into known shapes
# File: dataset/faces_0\01\frame_00422_depth.bin, Buffer size: 124406 bytes
# Could not interpret dataset/faces_0\01\frame_00422_depth.bin as float32.
# File: dataset/faces_0\01\frame_00423_depth.bin, Buffer size: 124638 bytes
# Could not interpret dataset/faces_0\01\frame_00423_depth.bin as float32.
# File: dataset/faces_0\01\frame_00424_depth.bin, Buffer size: 124722 bytes
# Could not interpret dataset/faces_0\01\frame_00424_depth.bin as float32.
# File: dataset/faces_0\01\frame_00425_depth.bin, Buffer size: 124232 bytes
# Loaded data as float32 with length: 31058
# Could not reshape depth data: Could not reshape array of size 31058 into known shapes
# File: dataset/faces_0\01\frame_00426_depth.bin, Buffer size: 123844 bytes
# Loaded data as float32 with length: 30961
# Could not reshape depth data: Could not reshape array of size 30961 into known shapes
# File: dataset/faces_0\01\frame_00427_depth.bin, Buffer size: 122878 bytes
# Could not interpret dataset/faces_0\01\frame_00427_depth.bin as float32.
# File: dataset/faces_0\01\frame_00428_depth.bin, Buffer size: 121806 bytes
# Could not interpret dataset/faces_0\01\frame_00428_depth.bin as float32.
# File: dataset/faces_0\01\frame_00429_depth.bin, Buffer size: 121244 bytes
# Loaded data as float32 with length: 30311
# Could not reshape depth data: Could not reshape array of size 30311 into known shapes
# File: dataset/faces_0\01\frame_00430_depth.bin, Buffer size: 120748 bytes
# Loaded data as float32 with length: 30187
# Could not reshape depth data: Could not reshape array of size 30187 into known shapes
# File: dataset/faces_0\01\frame_00431_depth.bin, Buffer size: 120070 bytes
# Could not interpret dataset/faces_0\01\frame_00431_depth.bin as float32.
# File: dataset/faces_0\01\frame_00432_depth.bin, Buffer size: 119232 bytes
# Loaded data as float32 with length: 29808
# Could not reshape depth data: Could not reshape array of size 29808 into known shapes
# File: dataset/faces_0\01\frame_00433_depth.bin, Buffer size: 118780 bytes
# Loaded data as float32 with length: 29695
# Could not reshape depth data: Could not reshape array of size 29695 into known shapes
# File: dataset/faces_0\01\frame_00434_depth.bin, Buffer size: 119602 bytes
# Could not interpret dataset/faces_0\01\frame_00434_depth.bin as float32.
# File: dataset/faces_0\01\frame_00435_depth.bin, Buffer size: 118516 bytes
# Loaded data as float32 with length: 29629
# Could not reshape depth data: Could not reshape array of size 29629 into known shapes
# File: dataset/faces_0\01\frame_00436_depth.bin, Buffer size: 118352 bytes
# Loaded data as float32 with length: 29588
# Could not reshape depth data: Could not reshape array of size 29588 into known shapes
# File: dataset/faces_0\01\frame_00437_depth.bin, Buffer size: 118662 bytes
# Could not interpret dataset/faces_0\01\frame_00437_depth.bin as float32.
# File: dataset/faces_0\01\frame_00438_depth.bin, Buffer size: 118328 bytes
# Loaded data as float32 with length: 29582
# Could not reshape depth data: Could not reshape array of size 29582 into known shapes
# File: dataset/faces_0\01\frame_00439_depth.bin, Buffer size: 118324 bytes
# Loaded data as float32 with length: 29581
# Could not reshape depth data: Could not reshape array of size 29581 into known shapes
# File: dataset/faces_0\01\frame_00440_depth.bin, Buffer size: 116912 bytes
# Loaded data as float32 with length: 29228
# Could not reshape depth data: Could not reshape array of size 29228 into known shapes
# File: dataset/faces_0\01\frame_00441_depth.bin, Buffer size: 116726 bytes
# Could not interpret dataset/faces_0\01\frame_00441_depth.bin as float32.
# File: dataset/faces_0\01\frame_00442_depth.bin, Buffer size: 116082 bytes
# Could not interpret dataset/faces_0\01\frame_00442_depth.bin as float32.
# File: dataset/faces_0\01\frame_00443_depth.bin, Buffer size: 116182 bytes
# Could not interpret dataset/faces_0\01\frame_00443_depth.bin as float32.
# File: dataset/faces_0\01\frame_00444_depth.bin, Buffer size: 115668 bytes
# Loaded data as float32 with length: 28917
# Could not reshape depth data: Could not reshape array of size 28917 into known shapes
# File: dataset/faces_0\01\frame_00445_depth.bin, Buffer size: 115722 bytes
# Could not interpret dataset/faces_0\01\frame_00445_depth.bin as float32.
# File: dataset/faces_0\01\frame_00446_depth.bin, Buffer size: 115746 bytes
# Could not interpret dataset/faces_0\01\frame_00446_depth.bin as float32.
# File: dataset/faces_0\01\frame_00447_depth.bin, Buffer size: 115492 bytes
# Loaded data as float32 with length: 28873
# Could not reshape depth data: Could not reshape array of size 28873 into known shapes
# File: dataset/faces_0\01\frame_00448_depth.bin, Buffer size: 115882 bytes
# Could not interpret dataset/faces_0\01\frame_00448_depth.bin as float32.
# File: dataset/faces_0\01\frame_00449_depth.bin, Buffer size: 116112 bytes
# Loaded data as float32 with length: 29028
# Could not reshape depth data: Could not reshape array of size 29028 into known shapes
# File: dataset/faces_0\01\frame_00450_depth.bin, Buffer size: 116504 bytes
# Loaded data as float32 with length: 29126
# Could not reshape depth data: Could not reshape array of size 29126 into known shapes
# File: dataset/faces_0\01\frame_00451_depth.bin, Buffer size: 116308 bytes
# Loaded data as float32 with length: 29077
# Could not reshape depth data: Could not reshape array of size 29077 into known shapes
# File: dataset/faces_0\01\frame_00452_depth.bin, Buffer size: 116764 bytes
# Loaded data as float32 with length: 29191
# Could not reshape depth data: Could not reshape array of size 29191 into known shapes
# File: dataset/faces_0\01\frame_00453_depth.bin, Buffer size: 116432 bytes
# Loaded data as float32 with length: 29108
# Could not reshape depth data: Could not reshape array of size 29108 into known shapes
# File: dataset/faces_0\01\frame_00454_depth.bin, Buffer size: 117000 bytes
# Loaded data as float32 with length: 29250
# Could not reshape depth data: Could not reshape array of size 29250 into known shapes
# File: dataset/faces_0\01\frame_00455_depth.bin, Buffer size: 117614 bytes
# Could not interpret dataset/faces_0\01\frame_00455_depth.bin as float32.
# File: dataset/faces_0\01\frame_00456_depth.bin, Buffer size: 118010 bytes
# Could not interpret dataset/faces_0\01\frame_00456_depth.bin as float32.
# File: dataset/faces_0\01\frame_00457_depth.bin, Buffer size: 118314 bytes
# Could not interpret dataset/faces_0\01\frame_00457_depth.bin as float32.
# File: dataset/faces_0\01\frame_00458_depth.bin, Buffer size: 118784 bytes
# Loaded data as float32 with length: 29696
# Could not reshape depth data: Could not reshape array of size 29696 into known shapes
# File: dataset/faces_0\01\frame_00459_depth.bin, Buffer size: 119218 bytes
# Could not interpret dataset/faces_0\01\frame_00459_depth.bin as float32.
# File: dataset/faces_0\01\frame_00460_depth.bin, Buffer size: 120890 bytes
# Could not interpret dataset/faces_0\01\frame_00460_depth.bin as float32.
# File: dataset/faces_0\01\frame_00461_depth.bin, Buffer size: 120316 bytes
# Loaded data as float32 with length: 30079
# Could not reshape depth data: Could not reshape array of size 30079 into known shapes
# File: dataset/faces_0\01\frame_00462_depth.bin, Buffer size: 121266 bytes
# Could not interpret dataset/faces_0\01\frame_00462_depth.bin as float32.
# File: dataset/faces_0\01\frame_00463_depth.bin, Buffer size: 120782 bytes
# Could not interpret dataset/faces_0\01\frame_00463_depth.bin as float32.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19800\913311193.py in <module>
#       1 # Use the function to preprocess the dataset
#       2 dataset_dir = 'dataset/'
# ----> 3 rgb_images, depth_images, poses, masks = preprocess_biwi_dataset(dataset_dir)
#       4
#       5 # Normalize images and masks
#
# ~\AppData\Local\Temp\ipykernel_19800\614640871.py in preprocess_biwi_dataset(dataset_dir)
#      63                 if sub_dir == 'faces_0' and file_name.endswith('_rgb.png'):
#      64                     rgb_img_path = os.path.join(folder_path, file_name)
# ---> 65                     rgb_img = cv2.imread(rgb_img_path)
#      66                     rgb_img = cv2.resize(rgb_img, (224, 224))
#      67                     rgb_images.append(rgb_img)
#
# KeyboardInterrupt:

# %%
# Updated function to handle your dataset structure
def preprocess_biwi_image(rgb_img_path, depth_img_path, img_size=(224, 224)):
    # Load RGB image
    rgb_img = load_img(rgb_img_path, target_size=img_size)
    rgb_img = img_to_array(rgb_img)

    # Load Depth image
    depth_img = cv2.imread(depth_img_path, cv2.IMREAD_UNCHANGED)
    depth_img = cv2.resize(depth_img, img_size)
    
    # Normalize depth image (optional)
    depth_img = depth_img.astype('float32')
    depth_img = depth_img / np.max(depth_img)  # Normalize to range [0, 1]

    return rgb_img, depth_img

def save_preprocessed_data(output_dir, rgb_img, depth_img, file_id):
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Save RGB and Depth images
    np.save(os.path.join(output_dir, f'{file_id}_rgb.npy'), rgb_img)
    np.save(os.path.join(output_dir, f'{file_id}_depth.npy'), depth_img)

def preprocess_biwi_dataset(dataset_dir, output_dir, img_size=(224, 224)):
    faces_dir = os.path.join(dataset_dir, 'faces_0')
    depth_dir = os.path.join(dataset_dir, 'head_pose_marks')
    annotations_dir = os.path.join(dataset_dir, 'db_annotations')

    subjects = [d for d in os.listdir(faces_dir) if os.path.isdir(os.path.join(faces_dir, d))]
    
    for subject in subjects:
        subject_face_path = os.path.join(faces_dir, subject)
        subject_depth_path = os.path.join(depth_dir, subject)
        subject_annotations_path = os.path.join(annotations_dir, subject)

        frames = sorted(os.listdir(subject_face_path))
        
        for frame in frames:
            frame_id = frame.split('.')[0]  # Assuming frames are named like 001.png
            rgb_img_path = os.path.join(subject_face_path, frame)
            depth_img_path = os.path.join(subject_depth_path, f'{frame_id}.png')

            # Check if the necessary files exist
            if not os.path.exists(rgb_img_path) or not os.path.exists(depth_img_path):
                continue

            # Preprocess the images
            rgb_img, depth_img = preprocess_biwi_image(rgb_img_path, depth_img_path, img_size)

            # Save the preprocessed data
            file_id = f'{subject}_{frame_id}'
            save_preprocessed_data(output_dir, rgb_img, depth_img, file_id)

            print(f'Processed and saved {file_id}')

# %%
def build_transfer_learning_model(input_shape=(224, 224, 3)):
    # Load the pre-trained ResNet50 model
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    # Optionally unfreeze the last few layers of ResNet50 for fine-tuning
    for layer in base_model.layers[:-10]:
        layer.trainable = False
    for layer in base_model.layers[-10:]:
        layer.trainable = True

    # Add skip connections and multi-scale feature fusion
    skip1 = base_model.get_layer('conv3_block4_out').output
    skip2 = base_model.get_layer('conv4_block6_out').output

    # Custom layers for depth estimation
    x = base_model.output
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Concatenate()([x, skip2])
    
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Concatenate()([x, skip1])
    
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2, 2))(x)
    
    x = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    
    # Create the model
    model = models.Model(inputs=base_model.input, outputs=x)
    return model


# Build and compile the model
model = build_transfer_learning_model()
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='mse')
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 512)    9437696     ['conv5_block3_out[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 14, 14, 512)  0          ['conv2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 1536  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'conv4_block6_out[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 256)  3539200     ['concatenate[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 28, 28, 256)  0          ['conv2d_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 768)  0           ['up_sampling2d_4[0][0]',
#                                                                   'conv3_block4_out[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  884864      ['concatenate_1[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 56, 56, 128)  0          ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 1)    1153        ['up_sampling2d_5[0][0]']
#
# ==================================================================================================
# Total params: 37,450,625
# Trainable params: 18,328,577
# Non-trainable params: 19,122,048
# __________________________________________________________________________________________________
